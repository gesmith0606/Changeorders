# %%
#imports 
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.ensemble import IsolationForest
import numpy as np
from sklearn.neighbors import LocalOutlierFactor
import matplotlib.pyplot as plt

# %%
#read in data 
filepath = Path("../Data/TracfloDataFullSet.csv")
changeorder = pd.read_csv(filepath,)
changeorder.head()
# Out:
#       total  paid_total   balance breakdowns_labor_0_type  \
# 0  133000.0         0.0  133000.0                     NaN
# 1   27248.0         0.0   27248.0                     NaN
# 2   -5000.0         0.0   -5000.0                     NaN
# 3   13852.0         0.0   13852.0                     NaN
# 4       0.0         0.0       0.0                     NaN
#
#    breakdowns_labor_0_hours  breakdowns_labor_0_rate  \
# 0                       8.0                      NaN
# 1                       8.0                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       8.0                      NaN
#
#    breakdowns_material_0_quantity breakdowns_material_0_unit  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
#
#    breakdowns_material_0_rate  Slug  ...  Labor Breakdown_quantity3  \
# 0                         NaN   193  ...                        NaN
# 1                         NaN   248  ...                        NaN
# 2                         NaN   251  ...                        NaN
# 3                         NaN   252  ...                        NaN
# 4                         NaN   253  ...                        NaN
#
#    Labor Breakdown_quantity total   Labor Breakdown_hours  \
# 0                                0                      8
# 1                                0                      8
# 2                                0                    NaN
# 3                                0                    NaN
# 4                                0                      8
#
#    Labor Breakdown_hours2  Labor Breakdown_hours3 Labor Breakdown_hourstotal  \
# 0                     NaN                     NaN                          8
# 1                     NaN                     NaN                          8
# 2                     NaN                     NaN                          0
# 3                     NaN                     NaN                          0
# 4                     NaN                     NaN                          8
#
#    Labor Breakdown_ratetotal  Material Breakdown_rate  \
# 0                      165.0                      NaN
# 1                        0.0                      NaN
# 2                        0.0                      NaN
# 3                        0.0                      NaN
# 4                        0.0                      NaN
#
#    Material Breakdown_quantity  Material Breakdown_unit
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
#
# [5 rows x 23 columns]

# %%
changeorder=changeorder.drop(columns="Scope of Work")

# %%
X=changeorder

# %%
# Splitting into Train and Test sets

X_train, X_test = train_test_split(X)

# %%
# Creating StandardScaler instance
#scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# train data
X_inliers = X_train

# %%
X_inliers.shape
# Out:
# (1499, 9)

# %%
# Generate some outliers
X_outliers = np.random.uniform(low=-4, high=4, size=(1499, 9))
X = np.r_[X_inliers, X_outliers]

# %%
n_outliers = len(X_outliers)
ground_truth = np.ones(len(X), dtype=int)
ground_truth[-n_outliers:] = -1

# %%
# fit the model for outlier detection (default)
clf = LocalOutlierFactor(n_neighbors=20, contamination=0.1)
# use fit_predict to compute the predicted labels of the training samples
# (when LOF is used for outlier detection, the estimator has no predict,
# decision_function and score_samples methods).
y_pred = clf.fit_predict(X)
n_errors = (y_pred != ground_truth).sum()
X_scores = clf.negative_outlier_factor_

# %%
plt.title("Local Outlier Factor (LOF)")
plt.scatter(X[:, 0], X[:, 1], color='k', s=3., label='Data points')
# plot circles with radius proportional to the outlier scores
radius = (X_scores.max() - X_scores) / (X_scores.max() - X_scores.min())
plt.scatter(X[:, 0], X[:, 1], s=1000 * radius, edgecolors='r',
            facecolors='none', label='Outlier scores')
plt.axis('tight')
plt.xlim((-5, 5))
plt.ylim((-5, 5))
plt.xlabel("prediction errors: %d" % (n_errors))
legend = plt.legend(loc='upper left')
legend.legendHandles[0]._sizes = [10]
legend.legendHandles[1]._sizes = [20]
plt.show()
